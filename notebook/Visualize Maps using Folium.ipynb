# %% [markdown]
# - Author: https://github.com/muz-rdm

# %%
import pandas as pd
import numpy as np
import itertools
import time
import re
import requests
import folium
import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter("ignore")
pd.set_option('display.max_columns', None)

# %%
# Load dataset from csv
df = pd.read_csv('../data/Hospital - Public v0.3 - Selangor (Cleaned) - Sheet1.csv')
df.shape
# Out:
# (23, 8)

# %%
df.head(5)
# Out:
#                         name           subtype  \
# 0            Hospital Ampang  General Hospital
# 1           Hospital Banting  General Hospital
# 2            Hospital Kajang  General Hospital
# 3  Hospital Kuala Kubu Bharu  General Hospital
# 4      Hospital Kuala Lumpur  General Hospital
#
#                                              address          tel  \
# 0  Jalan Mewah Utara, Taman Pandan Mewah, 68000 A...  03-42896000
# 1    Jalan Sultan Alam Shah, 42700 Banting, Selangor  03-31871333
# 2  Jalan Semenyih, Bandar Kajang, 43000 Kajang, S...  03-89133333
# 3  Jalan Hospital, Pekan Kuala Kubu Bharu, 44000 ...  03-60641333
# 4  Jalan Pahang, 50586 Kuala Lumpur, Wilayah Pers...  03-26155555
#
#                                coordinate  latitude   longitude  \
# 0   3.129074271635653, 101.76345046955092  3.129074  101.763451
# 1  2.8029233097006827, 101.49376351822603  2.802923  101.493764
# 2  2.9931321378088134, 101.79283506838564  2.993132  101.792835
# 3   3.5644453661423516, 101.6530586548904  3.564445  101.653059
# 4  3.1718054055442515, 101.70257576171394  3.171805  101.702576
#
#                                url_official
# 0                   http://hampg.moh.gov.my
# 1  https://jknselangor.moh.gov.my/hbanting/
# 2                   http://hkjg.moh.gov.my/
# 3      https://jknselangor.moh.gov.my/hkkb/
# 4                    http://hkl.moh.gov.my/

# %%
# Create folium map
center = (df['latitude'].mean(), df['longitude'].mean())
maps = folium.Map(location=center, 
                  tiles='openstreetmap', # Basemap
                  zoom_start=7)

# Add each point as a marker to the map
for index, row in df.iterrows():
    # Add popup text
    popup_text = "Name: {}<br> Type: {}<br> Address: {}<br> Telephone: {}<br> Website: {}<br> "
    popup_text = popup_text.format(row['name'],
                                   row['subtype'],
                                   row['address'],
                                   row['tel'],
                                   row['url_official'])
    popup_text = folium.Popup(popup_text, min_width=300, max_width=300)

    # Add each point to the map
    folium.CircleMarker([row['latitude'], row['longitude']],
                        radius = 3,
                        fill=True,
                        fill_opacity=1,
                        color='#273746', #Dark Blue
                        popup=popup_text).add_to(maps)

# %%
# Show map
maps
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e88d225bb865a05766119ffbda51e5ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e88d225bb865a05766119ffbda51e5ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e88d225bb865a05766119ffbda51e5ce = L.map(
#                 &quot;map_e88d225bb865a05766119ffbda51e5ce&quot;,
#                 {
#                     center: [3.1594274185652185, 101.6074301478261],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2cdf35224951d8c637250955acbb18ee = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e88d225bb865a05766119ffbda51e5ce);
#
#
#             var circle_marker_758fa73430b7159814d59e2f079a284e = L.circleMarker(
#                 [3.129074272, 101.7634505],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#273746&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#273746&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e88d225bb865a05766119ffbda51e5ce);
#
#
#         var popup_a1f5508a4008b316009441f0a1082c9e = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var html_311b1081a364a55853fe7a49848c029f = $(`&lt;div id=&quot;html_311b1081a364a55853fe7a49848c029f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: Hospital Ampang&lt;br&gt; Type: General Hospital&lt;br&gt; Address: Jalan Mewah Utara, Taman Pandan Mewah, 68000 Ampang, Selangor&lt;br&gt; Telephone: 03-42896000&lt;br&gt; Website: http://hampg.moh.gov.my&lt;br&gt; &lt;/div&gt;`)[0];
#                 popup_a1f5508a4008b316009441f0a1082c9e.setContent(html_311b1081a364a55853fe7a49848c029f);
#
#
#
#         circle_marker_758fa73430b7159814d59e2f079a284e.bindPopup(popup_a1f5508a4008b316009441f0a1082c9e)
#         ;
#
#
#
#
#             var circle_marker_3c378eda951ef92a4a42dd8514d631fa = L.circleMarker(
#                 [2.80292331, 101.4937635],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#273746&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#273746&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e88d225bb865a05766119ffbda51e5ce);
#
#
#         var popup_dfa8fc62370e43052f756918036e6558 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var html_0fcea9645b118f5aaf95b1b96c2b579c = $(`&lt;div id=&quot;html_0fcea9645b118f5aaf95b1b96c2b579c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: Hospital Banting&lt;br&gt; Type: General Hospital&lt;br&gt; Address: Jalan Sultan Alam Shah, 42700 Banting, Selangor&lt;br&gt; Telephone: 03-31871333&lt;br&gt; Website: https://jknselangor.moh.gov.my/hbanting/&lt;br&gt; &lt;/div&gt;`)[0];
#                 popup_dfa8fc62370e43052f756918036e6558.setContent(html_0fcea9645b118f5aaf95b1b96c2b579c);
#
#
#
#         circle_marker_3c378eda951ef92a4a42dd8514d631fa.bindPopup(popup_dfa8fc62370e43052f756918036e6558)
#         ;
#
#
#
#
#             var circle_marker_44bdbd79d6053fc70a1ffbdbe89f42e8 = L.circleMarker(
#                 [2.993132138, 101.7928351],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#273746&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#273746&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e88d225bb865a05766119ffbda51e5ce);
#
#
#         var popup_6c77b9e789d95b023ee74f136432448c = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var html_8fcf2e18b8fed6c89582a715b1879094 = $(`&lt;div id=&quot;html_8fcf2e18b8fed6c89582a715b1879094&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: Hospital Kajang&lt;br&gt; Type: General Hospital&lt;br&gt; Address: Jalan Semenyih, B

# %%
# Save map as html file
maps.save('../Output/Map_Hospital_Selangor_OSM.html')

# %% [markdown]
# ## Using Different Basemap Style

# %% [markdown]
# ### Cartodb Positron

# %%
# Create folium map
center = (df['latitude'].mean(), df['longitude'].mean())
maps = folium.Map(location=center, 
                  tiles='cartodb positron', # Basemap
                  zoom_start=7)

# Add each point as a marker to the map
for index, row in df.iterrows():
    # Add popup text
    popup_text = "Name: {}<br> Type: {}<br> Address: {}<br> Telephone: {}<br> Website: {}<br> "
    popup_text = popup_text.format(row['name'],
                                   row['subtype'],
                                   row['address'],
                                   row['tel'],
                                   row['url_official'])
    popup_text = folium.Popup(popup_text, min_width=300, max_width=300)

    # Add each point to the map
    folium.CircleMarker([row['latitude'], row['longitude']],
                        radius = 3,
                        fill=True,
                        fill_opacity=1,
                        color='#273746', # Dark Blue
                        popup=popup_text).add_to(maps)

# %%
# Show map
maps
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fedc9a3ccae9d92c649b86c1f457d875 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fedc9a3ccae9d92c649b86c1f457d875&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fedc9a3ccae9d92c649b86c1f457d875 = L.map(
#                 &quot;map_fedc9a3ccae9d92c649b86c1f457d875&quot;,
#                 {
#                     center: [3.1594274185652185, 101.6074301478261],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10377080d82f8008298f8f170290f219 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fedc9a3ccae9d92c649b86c1f457d875);
#
#
#             var circle_marker_397d54846e36496ca1ead6843f0bbbcb = L.circleMarker(
#                 [3.129074272, 101.7634505],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#273746&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#273746&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fedc9a3ccae9d92c649b86c1f457d875);
#
#
#         var popup_c77a033d1e29c7ad854b3777101ec465 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var html_a16cc991ae818773d079b30e0111abe6 = $(`&lt;div id=&quot;html_a16cc991ae818773d079b30e0111abe6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: Hospital Ampang&lt;br&gt; Type: General Hospital&lt;br&gt; Address: Jalan Mewah Utara, Taman Pandan Mewah, 68000 Ampang, Selangor&lt;br&gt; Telephone: 03-42896000&lt;br&gt; Website: http://hampg.moh.gov.my&lt;br&gt; &lt;/div&gt;`)[0];
#                 popup_c77a033d1e29c7ad854b3777101ec465.setContent(html_a16cc991ae818773d079b30e0111abe6);
#
#
#
#         circle_marker_397d54846e36496ca1ead6843f0bbbcb.bindPopup(popup_c77a033d1e29c7ad854b3777101ec465)
#         ;
#
#
#
#
#             var circle_marker_5f333bf1b75aa1cacd65842432ed3695 = L.circleMarker(
#                 [2.80292331, 101.4937635],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#273746&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#273746&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fedc9a3ccae9d92c649b86c1f457d875);
#
#
#         var popup_d7a36794ce0dbfe03bcdfb193e232eb2 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var html_ab1134d64745300814b8f909844707cc = $(`&lt;div id=&quot;html_ab1134d64745300814b8f909844707cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: Hospital Banting&lt;br&gt; Type: General Hospital&lt;br&gt; Address: Jalan Sultan Alam Shah, 42700 Banting, Selangor&lt;br&gt; Telephone: 03-31871333&lt;br&gt; Website: https://jknselangor.moh.gov.my/hbanting/&lt;br&gt; &lt;/div&gt;`)[0];
#                 popup_d7a36794ce0dbfe03bcdfb193e232eb2.setContent(html_ab1134d64745300814b8f909844707cc);
#
#
#
#         circle_marker_5f333bf1b75aa1cacd65842432ed3695.bindPopup(popup_d7a36794ce0dbfe03bcdfb193e232eb2)
#         ;
#
#
#
#
#             var circle_marker_7c4b8512c8bc736db9d24ce746644d95 = L.circleMarker(
#                 [2.993132138, 101.7928351],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#273746&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#273746&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fedc9a3ccae9d92c649b86c1f457d875);
#
#
#         var popup_7632cf9ea28a443742129ca7deb7ae98 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var html_0e989c1b81aba0c20df37365e42020dc = $(`&lt;div id=&quot;html_0e989c1b

# %% [markdown]
# ### Cartodb DarkMatter

# %%
# Create folium map
center = (df['latitude'].mean(), df['longitude'].mean())
maps = folium.Map(location=center, 
                  tiles='cartodbdark_matter', # Basemap
                  zoom_start=7)

# Add each point as a marker to the map
for index, row in df.iterrows():
    # Add popup text
    popup_text = "Name: {}<br> Type: {}<br> Address: {}<br> Telephone: {}<br> Website: {}<br> "
    popup_text = popup_text.format(row['name'],
                                   row['subtype'],
                                   row['address'],
                                   row['tel'],
                                   row['url_official'])
    popup_text = folium.Popup(popup_text, min_width=300, max_width=300)

    # Add each point to the map
    folium.CircleMarker([row['latitude'], row['longitude']],
                        radius = 3,
                        fill=True,
                        fill_opacity=1,
                        color='#FFC300', # Yellow
                        popup=popup_text).add_to(maps)

# %%
# Show map
maps
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b215d9a2980328bb53ce32658cafd4d6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b215d9a2980328bb53ce32658cafd4d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b215d9a2980328bb53ce32658cafd4d6 = L.map(
#                 &quot;map_b215d9a2980328bb53ce32658cafd4d6&quot;,
#                 {
#                     center: [3.1594274185652185, 101.6074301478261],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c96524220edb18d2ee074a24dee60a2c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b215d9a2980328bb53ce32658cafd4d6);
#
#
#             var circle_marker_473550feda4e81939e652fe7bb066b77 = L.circleMarker(
#                 [3.129074272, 101.7634505],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FFC300&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FFC300&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b215d9a2980328bb53ce32658cafd4d6);
#
#
#         var popup_e54b79b923a69b6b78da12c570617967 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var html_82a49dccc2d3ba39afd12199ea821c38 = $(`&lt;div id=&quot;html_82a49dccc2d3ba39afd12199ea821c38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: Hospital Ampang&lt;br&gt; Type: General Hospital&lt;br&gt; Address: Jalan Mewah Utara, Taman Pandan Mewah, 68000 Ampang, Selangor&lt;br&gt; Telephone: 03-42896000&lt;br&gt; Website: http://hampg.moh.gov.my&lt;br&gt; &lt;/div&gt;`)[0];
#                 popup_e54b79b923a69b6b78da12c570617967.setContent(html_82a49dccc2d3ba39afd12199ea821c38);
#
#
#
#         circle_marker_473550feda4e81939e652fe7bb066b77.bindPopup(popup_e54b79b923a69b6b78da12c570617967)
#         ;
#
#
#
#
#             var circle_marker_9a805aa4e5651ea008797c0149099cf0 = L.circleMarker(
#                 [2.80292331, 101.4937635],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FFC300&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FFC300&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b215d9a2980328bb53ce32658cafd4d6);
#
#
#         var popup_0ac0cffafdce7a47dc3848bb9c1df453 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var html_10fa8ebb47b05092e0052c37638cf7bd = $(`&lt;div id=&quot;html_10fa8ebb47b05092e0052c37638cf7bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: Hospital Banting&lt;br&gt; Type: General Hospital&lt;br&gt; Address: Jalan Sultan Alam Shah, 42700 Banting, Selangor&lt;br&gt; Telephone: 03-31871333&lt;br&gt; Website: https://jknselangor.moh.gov.my/hbanting/&lt;br&gt; &lt;/div&gt;`)[0];
#                 popup_0ac0cffafdce7a47dc3848bb9c1df453.setContent(html_10fa8ebb47b05092e0052c37638cf7bd);
#
#
#
#         circle_marker_9a805aa4e5651ea008797c0149099cf0.bindPopup(popup_0ac0cffafdce7a47dc3848bb9c1df453)
#         ;
#
#
#
#
#             var circle_marker_f951b33093ae1690a27d1739b135bd24 = L.circleMarker(
#                 [2.993132138, 101.7928351],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FFC300&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FFC300&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b215d9a2980328bb53ce32658cafd4d6);
#
#
#         var popup_ee9c49657821a5fc6333468edc72912e = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var html_2f346fcc707f1d2c5a7e30558cba3bbb = $(`&lt;div id=&quot;html_2f346fcc7

# %% [markdown]
# ### Stamen Terrain

# %%
# Create folium map
center = (df['latitude'].mean(), df['longitude'].mean())
maps = folium.Map(location=center, 
                  tiles='stamen terrain', # Basemap
                  zoom_start=7)

# Add each point as a marker to the map
for index, row in df.iterrows():
    # Add popup text
    popup_text = "Name: {}<br> Type: {}<br> Address: {}<br> Telephone: {}<br> Website: {}<br> "
    popup_text = popup_text.format(row['name'],
                                   row['subtype'],
                                   row['address'],
                                   row['tel'],
                                   row['url_official'])
    popup_text = folium.Popup(popup_text, min_width=300, max_width=300)

    # Add each point to the map
    folium.CircleMarker([row['latitude'], row['longitude']],
                        radius = 3,
                        fill=True,
                        fill_opacity=1,
                        color='#FFC300', # Yellow
                        popup=popup_text).add_to(maps)

# %%
# Show map
maps
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_62f6421b87c53680d29d772a8bcc95b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_62f6421b87c53680d29d772a8bcc95b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_62f6421b87c53680d29d772a8bcc95b4 = L.map(
#                 &quot;map_62f6421b87c53680d29d772a8bcc95b4&quot;,
#                 {
#                     center: [3.1594274185652185, 101.6074301478261],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6822e7f44328d1a37dfad061d1349ef3 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_62f6421b87c53680d29d772a8bcc95b4);
#
#
#             var circle_marker_ffd18035c8888067b77dddb85498266f = L.circleMarker(
#                 [3.129074272, 101.7634505],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FFC300&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FFC300&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_62f6421b87c53680d29d772a8bcc95b4);
#
#
#         var popup_e83217b99a6f2ce9bcb595824f82f67e = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var html_afb1a7b09f8d4067c9d0a2b98b3b0edc = $(`&lt;div id=&quot;html_afb1a7b09f8d4067c9d0a2b98b3b0edc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: Hospital Ampang&lt;br&gt; Type: General Hospital&lt;br&gt; Address: Jalan Mewah Utara, Taman Pandan Mewah, 68000 Ampang, Selangor&lt;br&gt; Telephone: 03-42896000&lt;br&gt; Website: http://hampg.moh.gov.my&lt;br&gt; &lt;/div&gt;`)[0];
#                 popup_e83217b99a6f2ce9bcb595824f82f67e.setContent(html_afb1a7b09f8d4067c9d0a2b98b3b0edc);
#
#
#
#         circle_marker_ffd18035c8888067b77dddb85498266f.bindPopup(popup_e83217b99a6f2ce9bcb595824f82f67e)
#         ;
#
#
#
#
#             var circle_marker_d3ee18037fd6165c34a6e8b63f38d9f9 = L.circleMarker(
#                 [2.80292331, 101.4937635],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FFC300&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FFC300&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_62f6421b87c53680d29d772a8bcc95b4);
#
#
#         var popup_07b83d48fa26f1e4dbc849e0080f1f2e = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var html_d2c57af5109a8b2613be790ea92c2374 = $(`&lt;div id=&quot;html_d2c57af5109a8b2613be790ea92c2374&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: Hospital Banting&lt;br&gt; Type: General Hospital&lt;br&gt; Address: Jalan Sultan Alam Shah, 42700 Banting, Selangor&lt;br&gt; Telephone: 03-31871333&lt;br&gt; Website: https://jknselangor.moh.gov.my/hbanting/&lt;br&gt; &lt;/div&gt;`)[0];
#                 popup_07b83d48fa26f1e4dbc849e0080f1f2e.setContent(html_d2c57af5109a8b2613be790ea92c2374);
#
#
#
#         circle_marker_d3ee18037fd6165c34a6e8b63f38d9f9.bindPopup(popup_07b83d48fa26f1e4dbc849e0080f1f2e)
#         ;
#
#
#
#
#             var circle_marker_1c2167f24cd831d5b8781589218b1885 = L.circleMarker(
#                 [2.993132138, 101.7928351],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FFC300&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FFC300&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_62f6421b87c53680d29d772a8bcc95b4);
#
#
#         var popup_379de2093452e72d55089a4fd9a268fb = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});

# %% [markdown]
# ### Stamen Toner

# %%
# Create folium map
center = (df['latitude'].mean(), df['longitude'].mean())
maps = folium.Map(location=center, 
                  tiles='stamen toner', # Basemap
                  zoom_start=7)

# Add each point as a marker to the map
for index, row in df.iterrows():
    # Add popup text
    popup_text = "Name: {}<br> Type: {}<br> Address: {}<br> Telephone: {}<br> Website: {}<br> "
    popup_text = popup_text.format(row['name'],
                                   row['subtype'],
                                   row['address'],
                                   row['tel'],
                                   row['url_official'])
    popup_text = folium.Popup(popup_text, min_width=300, max_width=300)

    # Add each point to the map
    folium.CircleMarker([row['latitude'], row['longitude']],
                        radius = 3,
                        fill=True,
                        fill_opacity=1,
                        color='#FFC300', # Yellow
                        popup=popup_text).add_to(maps)

# %%
# Show map
maps
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_821e452adc34624c85992125e132517a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_821e452adc34624c85992125e132517a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_821e452adc34624c85992125e132517a = L.map(
#                 &quot;map_821e452adc34624c85992125e132517a&quot;,
#                 {
#                     center: [3.1594274185652185, 101.6074301478261],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_970a510e9acb5d970f093539385cb947 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_821e452adc34624c85992125e132517a);
#
#
#             var circle_marker_f0c08a8fc483c1a494e2703fb8ecd9e8 = L.circleMarker(
#                 [3.129074272, 101.7634505],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FFC300&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FFC300&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_821e452adc34624c85992125e132517a);
#
#
#         var popup_3fe03565512df37b4bb6596bdc318d51 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var html_ad3fd055af43c77631ee8dfb5a1ff391 = $(`&lt;div id=&quot;html_ad3fd055af43c77631ee8dfb5a1ff391&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: Hospital Ampang&lt;br&gt; Type: General Hospital&lt;br&gt; Address: Jalan Mewah Utara, Taman Pandan Mewah, 68000 Ampang, Selangor&lt;br&gt; Telephone: 03-42896000&lt;br&gt; Website: http://hampg.moh.gov.my&lt;br&gt; &lt;/div&gt;`)[0];
#                 popup_3fe03565512df37b4bb6596bdc318d51.setContent(html_ad3fd055af43c77631ee8dfb5a1ff391);
#
#
#
#         circle_marker_f0c08a8fc483c1a494e2703fb8ecd9e8.bindPopup(popup_3fe03565512df37b4bb6596bdc318d51)
#         ;
#
#
#
#
#             var circle_marker_e4bb1593b5c133f2470553d107c56d69 = L.circleMarker(
#                 [2.80292331, 101.4937635],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FFC300&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FFC300&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_821e452adc34624c85992125e132517a);
#
#
#         var popup_06db1867159377910d41c2bbdb954bd8 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var html_3555d526826042bb067a61adf2127d6a = $(`&lt;div id=&quot;html_3555d526826042bb067a61adf2127d6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: Hospital Banting&lt;br&gt; Type: General Hospital&lt;br&gt; Address: Jalan Sultan Alam Shah, 42700 Banting, Selangor&lt;br&gt; Telephone: 03-31871333&lt;br&gt; Website: https://jknselangor.moh.gov.my/hbanting/&lt;br&gt; &lt;/div&gt;`)[0];
#                 popup_06db1867159377910d41c2bbdb954bd8.setContent(html_3555d526826042bb067a61adf2127d6a);
#
#
#
#         circle_marker_e4bb1593b5c133f2470553d107c56d69.bindPopup(popup_06db1867159377910d41c2bbdb954bd8)
#         ;
#
#
#
#
#             var circle_marker_4a1382bfe3057667d0e469c4d5f5ad1f = L.circleMarker(
#                 [2.993132138, 101.7928351],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FFC300&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FFC300&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_821e452adc34624c85992125e132517a);
#
#
#         var popup_023b62956973df21713b91d0067749e8 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});

# %% [markdown]
# ### ESRI Satellite Map

# %%
# Create folium map
center = (df['latitude'].mean(), df['longitude'].mean())
maps = folium.Map(location=center, 
                  zoom_start=7)

# Add tile layer to map
tile = folium.TileLayer(
      tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
      attr = 'Esri',
      name = 'Esri Satellite',
      overlay = False,
      control = True
      ).add_to(maps)

# Add each point as a marker to the map
for index, row in df.iterrows():
    # Add popup text
    popup_text = "Name: {}<br> Type: {}<br> Address: {}<br> Telephone: {}<br> Website: {}<br> "
    popup_text = popup_text.format(row['name'],
                                   row['subtype'],
                                   row['address'],
                                   row['tel'],
                                   row['url_official'])
    popup_text = folium.Popup(popup_text, min_width=300, max_width=300)

    # Add each point to the map
    folium.CircleMarker([row['latitude'], row['longitude']],
                        radius = 3,
                        fill=True,
                        fill_opacity=1,
                        color='#FFC300', # Yellow
                        popup=popup_text).add_to(maps)

# %%
# Show map
maps
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_60524ba32d5613e01854a626a38e33d0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_60524ba32d5613e01854a626a38e33d0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_60524ba32d5613e01854a626a38e33d0 = L.map(
#                 &quot;map_60524ba32d5613e01854a626a38e33d0&quot;,
#                 {
#                     center: [3.1594274185652185, 101.6074301478261],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff6d1cbb8c263bf4eb0e755dedf0fa1f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_60524ba32d5613e01854a626a38e33d0);
#
#
#             var tile_layer_a1531e6ab1f3b4679fe2e6fa03d5071a = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Esri&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_60524ba32d5613e01854a626a38e33d0);
#
#
#             var circle_marker_837b12fa95733a59617300368f6674db = L.circleMarker(
#                 [3.129074272, 101.7634505],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FFC300&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FFC300&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_60524ba32d5613e01854a626a38e33d0);
#
#
#         var popup_b6265964abfdddf7d9c54afaa999d4ca = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var html_80d479343aca86370d81d5007cf2f647 = $(`&lt;div id=&quot;html_80d479343aca86370d81d5007cf2f647&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: Hospital Ampang&lt;br&gt; Type: General Hospital&lt;br&gt; Address: Jalan Mewah Utara, Taman Pandan Mewah, 68000 Ampang, Selangor&lt;br&gt; Telephone: 03-42896000&lt;br&gt; Website: http://hampg.moh.gov.my&lt;br&gt; &lt;/div&gt;`)[0];
#                 popup_b6265964abfdddf7d9c54afaa999d4ca.setContent(html_80d479343aca86370d81d5007cf2f647);
#
#
#
#         circle_marker_837b12fa95733a59617300368f6674db.bindPopup(popup_b6265964abfdddf7d9c54afaa999d4ca)
#         ;
#
#
#
#
#             var circle_marker_3ceb05adf7de7bc6d4bb0bf3063108c5 = L.circleMarker(
#                 [2.80292331, 101.4937635],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FFC300&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FFC300&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_60524ba32d5613e01854a626a38e33d0);
#
#
#         var popup_442f4b0da3b7dd352ff01df9eacb3896 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 300});
#
#
#
#                 var html_08b77585ccd5118eb69999b72fb365a3 = $(`&lt;div id=&quot;html_08b77585ccd5118eb69999b72fb365a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Name: Hospital Banting&lt;br&gt; Type: General Hospital&lt;br&gt; Address: Jalan Sultan Alam Shah, 42700 Banting, Selangor&lt;br&gt; Telephone: 03-31871333&lt;br&gt; Website: https://jknselangor.moh.gov.my/hbanting/&lt;br&gt; &lt;/div&gt;`)[0];
#                 popup_442f4b0da3b7dd352ff01df9eacb3896.setContent(html_08b77585ccd5118eb69999b72fb365a3);
#
#
#
#         circle_marker_3ceb05adf7de7bc6d4bb0bf3063108c5.bindPopup(popup_442f4b0da3b7dd352ff01df9eacb3896)
#         ;
#
#
#
#
#             var circle_marker_e01f585d899d4bd432d565c7a809c0c7 = L.circleMarker(
#                 [2.993132138, 101.7928351],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FFC300&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FFC300&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;
